# %%
import os
from bs4 import BeautifulSoup
import pandas as pd

# %%
df_list = []
folder = 'data/rt_html'
for movie in os.listdir(folder):
    with open(os.path.join(folder, movie)) as file:
        soup = BeautifulSoup(file, 'lxml')
        title = soup.find('title').contents[0][:-len(' - Rotten Tomatoes')]
        audience_score = soup.find('div', class_='audience-score meter').find('span').contents[0][:-1]
        num_audience_ratings = soup.find('div', class_='audience-info hidden-xs superPageFontColor')\
                                   .find_all('div')[1].contents[2].strip().replace(',', '')
        df_list.append({'title': title,
                        'audience_score': int(audience_score),
                        'number_of_audience_ratings': int(num_audience_ratings)})
df = pd.DataFrame(df_list, columns = ['title', 'audience_score', 'number_of_audience_ratings'])

# %%
df
# Out:
#                                                 title  audience_score  \
# 0              12 Angry Men (Twelve Angry Men) (1957)              97
# 1                                 The 39 Steps (1935)              86
# 2                 The Adventures of Robin Hood (1938)              89
# 3                                All About Eve (1950)              94
# 4               All Quiet on the Western Front (1930)              89
# 5                                   Casablanca (1942)              95
# 6                                 Frankenstein (1931)              87
# 7                                    King Kong (1933)              86
# 8                                        Laura (1944)              91
# 9                                            M (1931)              95
# 10                          The Maltese Falcon (1941)              91
# 11                                  Metropolis (1927)              92
# 12                                 Rear Window (1954)              95
# 13                                     Rebecca (1940)              92
# 14                    A Streetcar Named Desire (1951)              90
# 15                               Touch of Evil (1958)              92
# 16                                   High Noon (1952)              89
# 17             Snow White and the Seven Dwarfs (1937)              78
# 18                            12 Years a Slave (2013)              90
# 19      The 400 Blows (Les Quatre cents coups) (1959)              94
# 20                                       Alien (1979)              94
# 21                              Apocalypse Now (1979)              94
# 22                                        Argo (2012)              90
# 23       Army of Shadows (L'ArmÃ©e des ombres) (1969)              94
# 24                                     Arrival (2016)              82
# 25                                 Baby Driver (2017)              89
# 26                         Battleship Potemkin (1925)              85
# 27                          A Hard Day's Night (1964)              89
# 28       Bicycle Thieves (Ladri di biciclette) (1949)              94
# 29                                     Boyhood (2014)              81
# ..                                                ...             ...
# 70                                       Selma (2015)              86
# 71        Seven Samurai (Shichinin no Samurai) (1956)              97
# 72                         Singin' in the Rain (1952)              95
# 73                                     Skyfall (2012)              86
# 74                                   Spotlight (2015)              93
# 75                                   Star Trek (2009)              91
# 76  Star Wars: Episode VII - The Force Awakens (2015)              89
# 77                            Sunset Boulevard (1950)              95
# 78                                 Taxi Driver (1976)              93
# 79                                The Babadook (2014)              72
# 80  The Battle of Algiers (La Battaglia di Algeri)...              95
# 81                                The Big Sick (2017)              90
# 82  The Cabinet of Dr. Caligari (Das Cabinet des D...              89
# 83                              The Conformist (1970)              91
# 84                             The Dark Knight (2008)              94
# 85              The Good, the Bad and the Ugly (1966)              97
# 86                             The Jungle Book (2016)              86
# 87                               The Third Man (1949)              93
# 88                            The Wizard of Oz (1939)              89
# 89                                The Wrestler (2008)              88
# 90            Tokyo Story (TÃ´kyÃ´ monogatari) (1953)              93
# 91                                   Toy Story (1995)              92
# 92                                 Toy Story 2 (1999)              86
# 93                                 Toy Story 3 (2010)              89
# 94            The Treasure of the Sierra Madre (1948)              93
# 95                                          Up (2009)              90
# 96                                     Vertigo (1958)              93
# 97                           The Wages of Fear (1953)              95
# 98                                Wonder Woman (2017)              90
# 99                                    Zootopia (2016)              92
#
#     number_of_audience_ratings
# 0                       103672
# 1                        23647
# 2                        33584
# 3                        44564
# 4                        17768
# 5                       355952
# 6                        41140
# 7                        89669
# 8                        10481
# 9                        35778
# 10                       57268
# 11                       62018
# 12                      149458
# 13                       39026
# 14                       54761
# 15                       30867
# 16                       25065
# 17                      469510
# 18                      138789
# 19                       38368
# 20                      457186
# 21                      284606
# 22                      207373
# 23                        7011
# 24                       78740
# 25                       48114
# 26                       18709
# 27                       50067
# 28                       33723
# 29                       88478
# ..                         ...
# 70                       60533
# 71                       90049
# 72                      137643
# 73                      372497
# 74                       68142
# 75                      746458
# 76                      222789
# 77                       52783
# 78                      258405
# 79                       37024
# 80                       14267
# 81                       23391
# 82                       27163
# 83                        8529
# 84                     1827436
# 85                      238420
# 86                       92856
# 87                       53081
# 88                      874425
# 89                      139795
# 90                       11325
# 91                     1107731
# 92                      998186
# 93                      605098
# 94                       25627
# 95                     1201878
# 96                      101454
# 97                        8536
# 98                      112955
# 99                       98633
#
# [100 rows x 3 columns]
