# %%
# -----------------------------------------------
# ANÁLISE DE REMUNERAÇÃO DOS SERVIDORES ESTADUAIS
# -----------------------------------------------
#
# Autor: Rodolfo Viana
# Início da análise: 21 de dezembro de 2017
# Previsão de finalização da análise: 26 de dezembro de 2017
# Fonte dos dados: Transparência SP - http://www.transparencia.sp.gov.br/busca-agentes.html
# Recorte: De janeiro de 2017 a outubro de 2017 (último mês disponível)
# Manipulação dos dados: acréscimo da coluna 'mes' nos arquivos .csv executado em SQL

import pandas as pd
import numpy as np

jan = pd.read_csv('Janeiro_2017.csv', sep=';',
                  converters={'remuneracao_mes': lambda x: float(x.replace(',','.')), 
                              'ferias_13salario': lambda x: float(x.replace(',','.')), 
                              'pagtos_eventuais': lambda x: float(x.replace(',','.')), 
                              'licenca_premio_indenizada': lambda x: float(x.replace(',','.')), 
                              'abono_permanencia_outras_inden': lambda x: float(x.replace(',','.')), 
                              'redutor_salarial': lambda x: float(x.replace(',','.')), 
                              'total_liquido': lambda x: float(x.replace(',','.'))},
                  low_memory=False)
fev = pd.read_csv('Fevereiro_2017.csv', sep=';',
                  converters={'remuneracao_mes': lambda x: float(x.replace(',','.')), 
                              'ferias_13salario': lambda x: float(x.replace(',','.')), 
                              'pagtos_eventuais': lambda x: float(x.replace(',','.')), 
                              'licenca_premio_indenizada': lambda x: float(x.replace(',','.')), 
                              'abono_permanencia_outras_inden': lambda x: float(x.replace(',','.')), 
                              'redutor_salarial': lambda x: float(x.replace(',','.')), 
                              'total_liquido': lambda x: float(x.replace(',','.'))},
                  low_memory=False)
mar = pd.read_csv('Marco_2017.csv', sep=';',
                  converters={'remuneracao_mes': lambda x: float(x.replace(',','.')), 
                              'ferias_13salario': lambda x: float(x.replace(',','.')), 
                              'pagtos_eventuais': lambda x: float(x.replace(',','.')), 
                              'licenca_premio_indenizada': lambda x: float(x.replace(',','.')), 
                              'abono_permanencia_outras_inden': lambda x: float(x.replace(',','.')), 
                              'redutor_salarial': lambda x: float(x.replace(',','.')), 
                              'total_liquido': lambda x: float(x.replace(',','.'))},
                  low_memory=False)
abr = pd.read_csv('Abril_2017.csv', sep=';',
                  converters={'remuneracao_mes': lambda x: float(x.replace(',','.')), 
                              'ferias_13salario': lambda x: float(x.replace(',','.')), 
                              'pagtos_eventuais': lambda x: float(x.replace(',','.')), 
                              'licenca_premio_indenizada': lambda x: float(x.replace(',','.')), 
                              'abono_permanencia_outras_inden': lambda x: float(x.replace(',','.')), 
                              'redutor_salarial': lambda x: float(x.replace(',','.')), 
                              'total_liquido': lambda x: float(x.replace(',','.'))},
                  low_memory=False)
mai = pd.read_csv('Maio_2017.csv', sep=';',
                  converters={'remuneracao_mes': lambda x: float(x.replace(',','.')), 
                              'ferias_13salario': lambda x: float(x.replace(',','.')), 
                              'pagtos_eventuais': lambda x: float(x.replace(',','.')), 
                              'licenca_premio_indenizada': lambda x: float(x.replace(',','.')), 
                              'abono_permanencia_outras_inden': lambda x: float(x.replace(',','.')), 
                              'redutor_salarial': lambda x: float(x.replace(',','.')), 
                              'total_liquido': lambda x: float(x.replace(',','.'))},
                  low_memory=False)
jun = pd.read_csv('Junho_2017.csv', sep=';',
                  converters={'remuneracao_mes': lambda x: float(x.replace(',','.')), 
                              'ferias_13salario': lambda x: float(x.replace(',','.')), 
                              'pagtos_eventuais': lambda x: float(x.replace(',','.')), 
                              'licenca_premio_indenizada': lambda x: float(x.replace(',','.')), 
                              'abono_permanencia_outras_inden': lambda x: float(x.replace(',','.')), 
                              'redutor_salarial': lambda x: float(x.replace(',','.')), 
                              'total_liquido': lambda x: float(x.replace(',','.'))},
                  low_memory=False)
jul = pd.read_csv('Julho_2017.csv', sep=';',
                  converters={'remuneracao_mes': lambda x: float(x.replace(',','.')), 
                              'ferias_13salario': lambda x: float(x.replace(',','.')), 
                              'pagtos_eventuais': lambda x: float(x.replace(',','.')), 
                              'licenca_premio_indenizada': lambda x: float(x.replace(',','.')), 
                              'abono_permanencia_outras_inden': lambda x: float(x.replace(',','.')), 
                              'redutor_salarial': lambda x: float(x.replace(',','.')), 
                              'total_liquido': lambda x: float(x.replace(',','.'))},
                  low_memory=False)
ago = pd.read_csv('Agosto_2017.csv', sep=';',
                  converters={'remuneracao_mes': lambda x: float(x.replace(',','.')), 
                              'ferias_13salario': lambda x: float(x.replace(',','.')), 
                              'pagtos_eventuais': lambda x: float(x.replace(',','.')), 
                              'licenca_premio_indenizada': lambda x: float(x.replace(',','.')), 
                              'abono_permanencia_outras_inden': lambda x: float(x.replace(',','.')), 
                              'redutor_salarial': lambda x: float(x.replace(',','.')), 
                              'total_liquido': lambda x: float(x.replace(',','.'))},
                  low_memory=False)
sete = pd.read_csv('Setembro_2017.csv', sep=';',
                   converters={'remuneracao_mes': lambda x: float(x.replace(',','.')), 
                              'ferias_13salario': lambda x: float(x.replace(',','.')), 
                              'pagtos_eventuais': lambda x: float(x.replace(',','.')), 
                              'licenca_premio_indenizada': lambda x: float(x.replace(',','.')), 
                              'abono_permanencia_outras_inden': lambda x: float(x.replace(',','.')), 
                              'redutor_salarial': lambda x: float(x.replace(',','.')), 
                              'total_liquido': lambda x: float(x.replace(',','.'))},
                   low_memory=False)
out = pd.read_csv('Outubro_2017.csv', sep=';',
                  converters={'remuneracao_mes': lambda x: float(x.replace(',','.')), 
                              'ferias_13salario': lambda x: float(x.replace(',','.')), 
                              'pagtos_eventuais': lambda x: float(x.replace(',','.')), 
                              'licenca_premio_indenizada': lambda x: float(x.replace(',','.')), 
                              'abono_permanencia_outras_inden': lambda x: float(x.replace(',','.')), 
                              'redutor_salarial': lambda x: float(x.replace(',','.')), 
                              'total_liquido': lambda x: float(x.replace(',','.'))},
                  low_memory=False)
data = pd.concat([jan, fev, mar, abr, mai, jun, jul, ago, sete, out])

# %%
print('Registros em análise: ', len(data))
print('Servidores em análise (exceto não identificados): ', data['nome'].nunique()-1)
print('Total de órgãos em análise: ', data['orgao'].nunique())
print('Total de remunerações: R$ ', data['remuneracao_mes'].sum())
print('Total de valores pagos: R$ ', data['total_liquido'].sum())
# Out:
# Registros em análise:  10826760
# Servidores em análise (exceto não identificados):  1013649
# Total de órgãos em análise:  88
# Total de remunerações: R$  46610796224.53473
# Total de valores pagos: R$  37054924204.00506

# %%
data.head(10)
# Out:
#                            nome                                    cargo  \
# 0       AAIRON TELES DE CAMARGO                   OFICIAL ADMINISTRATIVO
# 1       AAIRON TELES DE CAMARGO                             NAO SERVIDOR
# 2         AALAN DA SILVA ARAUJO                                 SD 2C PM
# 3    AARAN ESTEVAO LIMA BARBOSA                                 1TEN  PM
# 4             AARAO DE OLIVEIRA                                 MAJ   PM
# 5     AARON DE OLIVEIRA BARBOSA           AGENTE TECNICO ASSIST. A SAUDE
# 6        AARON DOUGLAS OLIVEIRA                                 SD 1C PM
# 7         AARON GABRIEL MIRANDA  BENEFICIARIO DE SERVIDOR ESTADUAL-IPESP
# 8  AARON LUCAS MOLINA BENEDETTI                                 SD 1C PM
# 9        AARON SALES DE ALMEIDA                                 SD 1C PM
#
#      orgao  remuneracao_mes  ferias_13salario  pagtos_eventuais  \
# 0   SEPLAN          1418.81              0.00              12.3
# 1   DETRAN           819.00              0.00               0.0
# 2       PM          2357.76              0.00               0.0
# 3       PM          9037.23              0.00               0.0
# 4   SPPREV         13542.59              0.00               0.0
# 5  HCFMUSP          4167.27              0.00               0.0
# 6       PM          3500.58              0.00               0.0
# 7   SPPREV          1699.19              0.00               0.0
# 8       PM          3446.05           1405.64               0.0
# 9       PM          4521.92              0.00               0.0
#
#    licenca_premio_indenizada  abono_permanencia_outras_inden  \
# 0                       0.00                          249.27
# 1                       0.00                            0.00
# 2                       0.00                          100.28
# 3                       0.00                          376.05
# 4                       0.00                            0.00
# 5                       0.00                            0.00
# 6                       0.00                          476.33
# 7                       0.00                            0.00
# 8                    3446.05                          752.10
# 9                       0.00                          551.54
#
#    redutor_salarial  total_liquido      mes
# 0               0.0        1665.66  Janeiro
# 1               0.0         712.53  Janeiro
# 2               0.0        1366.75  Janeiro
# 3               0.0        6711.26  Janeiro
# 4               0.0       10537.11  Janeiro
# 5               0.0        2478.66  Janeiro
# 6               0.0        3439.78  Janeiro
# 7               0.0        1699.19  Janeiro
# 8               0.0        7443.62  Janeiro
# 9               0.0        3326.01  Janeiro
